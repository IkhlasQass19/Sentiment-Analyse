# %% [markdown]
# Import Bib

# %%
# utilisée pour les calculs mathématiques en Python, spécialement pour les tableaux à plusieurs dimensions.
import numpy as np
#  convertir des données textuelles en séquences numériques qui peuvent être utilisées comme entrées pour les réseaux de neurones.
from keras.preprocessing.text import Tokenizer
# permet d'assurer que toutes les séquences de données ont la même longueur et peuvent donc être utilisées comme entrées pour le modèle,ajoutant des zéros à la fin des séquences plus courtes pour s'assurer que toutes les entrées ont la même longueur 
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Sequential est une classe de Keras qui permet de définir et créer des modèles de réseaux de neurones séquentiels en permettant d'ajouter les couches du modèle les unes après les autres de manière simple et conviviale
from keras.models import Sequential
# import des couches Embedding[vecteur de densite latente], GRU et Dense(effectuer les calculs de regression) pour le modèle RNN
from keras.layers import Embedding, GRU, Dense 
# stocker et manipuler des données tabulaires, telles que des tableaux de données enregistrés dans des fichiers CSV
import pandas as pd

import keras
import pickle 
from keras.models import load_model
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Create Model

# %%
# Chargement des données de sentiments préparées dans un DataFrame de Pandas
data = pd.read_csv('yelp.csv')

# Séparation des données en entrée (textes) et étiquettes (sentiments)
texts = data['sentence'].values # tous les textes sont stockés dans le tableau texts
labels = data['label'].values # toutes les étiquettes sont stockées dans le tableau labels

# Tokenisation des textes
tokenizer = Tokenizer(num_words=10000) # définition du tokenizer avec une limite de 10000 mots
tokenizer.fit_on_texts(texts) # entraînement du tokenizer sur les textes
# tokenizer.fit_on_texts(texts) entraîne le tokenizer sur les textes. Cela signifie que le tokenizer analyse les textes et crée un dictionnaire de mots uniques, avec un identifiant unique pour chaque mot.
sequences = tokenizer.texts_to_sequences(texts) # tokenisation des textes
# effectue la tokenisation des textes. Cela signifie que le tokenizer convertit chaque séquence de textes en une séquence d'identificateurs uniques. Les séquences de textes sont remplacées par des séquences d'entiers, où chaque entier représente un mot unique dans le dictionnaire créé lors de l'entraînement.

# Pad sequences pour avoir la même longueur pour tous les textes
padded_sequences = pad_sequences(sequences, maxlen=100) # padding des séquences de tokenisation pour toutes les avoir de la même longueur

# Définition du modèle RNN
model = Sequential([
    Embedding(10000, 128, input_length=100), # première couche : embedding
       GRU(128), # deuxième couche : GRU
     Dense(1, activation='sigmoid') # troisième couche : dense avec une activation sigmoïde pour avoir un output binaire
   ])

# Compilation du modèle
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # choix de la fonction de coût, de l'optimiseur et des métriques à suivre lors de l'entraînement

# Entraînement du modèle

history = model.fit(padded_sequences, labels, epochs=100, validation_split=0.2) # entraînement sur les séquences padded et les étiquettes avec 10 epochs et une validation sur 20% des données
# Après l'entraînement
model.save('sentiment_analysis_model.h5')


# Sauvegarde du tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 25/25 [==============================] - 6s 120ms/step - loss: 0.6789 - accuracy: 0.5625 - val_loss: 0.7832 - val_accuracy: 0.2400
# Epoch 2/100
# 25/25 [==============================] - 3s 105ms/step - loss: 0.5682 - accuracy: 0.6975 - val_loss: 0.5709 - val_accuracy: 0.7250
# Epoch 3/100
# 25/25 [==============================] - 3s 103ms/step - loss: 0.3574 - accuracy: 0.8900 - val_loss: 0.5975 - val_accuracy: 0.6900
# Epoch 4/100
# 25/25 [==============================] - 2s 96ms/step - loss: 0.2562 - accuracy: 0.9413 - val_loss: 0.6373 - val_accuracy: 0.6450
# Epoch 5/100
# 25/25 [==============================] - 2s 97ms/step - loss: 0.1665 - accuracy: 0.9650 - val_loss: 0.6370 - val_accuracy: 0.6850
# Epoch 6/100
# 25/25 [==============================] - 3s 101ms/step - loss: 0.1061 - accuracy: 0.9787 - val_loss: 0.6740 - val_accuracy: 0.6950
# Epoch 7/100
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0686 - accuracy: 0.9862 - val_loss: 0.7119 - val_accuracy: 0.7000
# Epoch 8/100
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0439 - accuracy: 0.9937 - val_loss: 0.7851 - val_accuracy: 0.7050
# Epoch 9/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0295 - accuracy: 0.9937 - val_loss: 0.8311 - val_accuracy: 0.7000
# Epoch 10/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0192 - accuracy: 0.9975 - val_loss: 0.8816 - val_accuracy: 0.7000
# Epoch 11/100
# 25/25 [==============================] - 2s 97ms/step - loss: 0.0126 - accuracy: 0.9987 - val_loss: 0.9423 - val_accuracy: 0.7000
# Epoch 12/100
# 25/25 [==============================] - 3s 105ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.9775 - val_accuracy: 0.7200
# Epoch 13/100
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.0178 - val_accuracy: 0.7250
# Epoch 14/100
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.0676 - val_accuracy: 0.7200
# Epoch 15/100
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.1057 - val_accuracy: 0.7200
# Epoch 16/100
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1299 - val_accuracy: 0.7250
# Epoch 17/100
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1603 - val_accuracy: 0.7250
# Epoch 18/100
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1908 - val_accuracy: 0.7250
# Epoch 19/100
# 25/25 [==============================] - 3s 109ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2070 - val_accuracy: 0.7250
# Epoch 20/100
# 25/25 [==============================] - 3s 103ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2316 - val_accuracy: 0.7250
# Epoch 21/100
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2604 - val_accuracy: 0.7200
# Epoch 22/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2855 - val_accuracy: 0.7250
# Epoch 23/100
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.2985 - val_accuracy: 0.7250
# Epoch 24/100
# 25/25 [==============================] - 2s 90ms/step - loss: 9.0667e-04 - accuracy: 1.0000 - val_loss: 1.3161 - val_accuracy: 0.7250
# Epoch 25/100
# 25/25 [==============================] - 2s 90ms/step - loss: 8.1312e-04 - accuracy: 1.0000 - val_loss: 1.3358 - val_accuracy: 0.7250
# Epoch 26/100
# 25/25 [==============================] - 2s 89ms/step - loss: 7.2517e-04 - accuracy: 1.0000 - val_loss: 1.3461 - val_accuracy: 0.7250
# Epoch 27/100
# 25/25 [==============================] - 2s 92ms/step - loss: 6.5464e-04 - accuracy: 1.0000 - val_loss: 1.3620 - val_accuracy: 0.7250
# Epoch 28/100
# 25/25 [==============================] - 2s 84ms/step - loss: 5.9793e-04 - accuracy: 1.0000 - val_loss: 1.3698 - val_accuracy: 0.7250
# Epoch 29/100
# 25/25 [==============================] - 2s 83ms/step - loss: 5.4350e-04 - accuracy: 1.0000 - val_loss: 1.3912 - val_accuracy: 0.7250
# Epoch 30/100
# 25/25 [==============================] - 2s 80ms/step - loss: 4.9534e-04 - accuracy: 1.0000 - val_loss: 1.4013 - val_accuracy: 0.7250
# Epoch 31/100
# 25/25 [==============================] - 2s 81ms/step - loss: 4.5964e-04 - accuracy: 1.0000 - val_loss: 1.4150 - val_accuracy: 0.7250
# Epoch 32/100
# 25/25 [==============================] - 2s 93ms/step - loss: 4.2227e-04 - accuracy: 1.0000 - val_loss: 1.4319 - val_accuracy: 0.7250
# Epoch 33/100
# 25/25 [==============================] - 2s 83ms/step - loss: 3.9128e-04 - accuracy: 1.0000 - val_loss: 1.4427 - val_accuracy: 0.7250
# Epoch 34/100
# 25/25 [==============================] - 2s 82ms/step - loss: 3.6070e-04 - accuracy: 1.0000 - val_loss: 1.4490 - val_accuracy: 0.7250
# Epoch 35/100
# 25/25 [==============================] - 2s 81ms/step - loss: 3.3748e-04 - accuracy: 1.0000 - val_loss: 1.4595 - val_accuracy: 0.7250
# Epoch 36/100
# 25/25 [==============================] - 2s 75ms/step - loss: 3.1530e-04 - accuracy: 1.0000 - val_loss: 1.4645 - val_accuracy: 0.7250
# Epoch 37/100
# 25/25 [==============================] - 2s 89ms/step - loss: 2.9380e-04 - accuracy: 1.0000 - val_loss: 1.4821 - val_accuracy: 0.7250
# Epoch 38/100
# 25/25 [==============================] - 2s 75ms/step - loss: 2.7528e-04 - accuracy: 1.0000 - val_loss: 1.4923 - val_accuracy: 0.7200
# Epoch 39/100
# 25/25 [==============================] - 2s 76ms/step - loss: 2.5800e-04 - accuracy: 1.0000 - val_loss: 1.4990 - val_accuracy: 0.7200
# Epoch 40/100
# 25/25 [==============================] - 2s 82ms/step - loss: 2.4224e-04 - accuracy: 1.0000 - val_loss: 1.5085 - val_accuracy: 0.7200
# Epoch 41/100
# 25/25 [==============================] - 2s 84ms/step - loss: 2.2961e-04 - accuracy: 1.0000 - val_loss: 1.5146 - val_accuracy: 0.7200
# Epoch 42/100
# 25/25 [==============================] - 2s 84ms/step - loss: 2.1500e-04 - accuracy: 1.0000 - val_loss: 1.5236 - val_accuracy: 0.7200
# Epoch 43/100
# 25/25 [==============================] - 2s 91ms/step - loss: 2.0363e-04 - accuracy: 1.0000 - val_loss: 1.5351 - val_accuracy: 0.7200
# Epoch 44/100
# 25/25 [==============================] - 2s 82ms/step - loss: 1.9238e-04 - accuracy: 1.0000 - val_loss: 1.5436 - val_accuracy: 0.7200
# Epoch 45/100
# 25/25 [==============================] - 2s 74ms/step - loss: 1.8221e-04 - accuracy: 1.0000 - val_loss: 1.5496 - val_accuracy: 0.7200
# Epoch 46/100
# 25/25 [==============================] - 2s 74ms/step - loss: 1.7290e-04 - accuracy: 1.0000 - val_loss: 1.5559 - val_accuracy: 0.7200
# Epoch 47/100
# 25/25 [==============================] - 2s 74ms/step - loss: 1.6534e-04 - accuracy: 1.0000 - val_loss: 1.5705 - val_accuracy: 0.7200
# Epoch 48/100
# 25/25 [==============================] - 2s 83ms/step - loss: 1.5607e-04 - accuracy: 1.0000 - val_loss: 1.5731 - val_accuracy: 0.7200
# Epoch 49/100
# 25/25 [==============================] - 2s 82ms/step - loss: 1.4954e-04 - accuracy: 1.0000 - val_loss: 1.5733 - val_accuracy: 0.7200
# Epoch 50/100
# 25/25 [==============================] - 2s 85ms/step - loss: 1.4142e-04 - accuracy: 1.0000 - val_loss: 1.5868 - val_accuracy: 0.7200
# Epoch 51/100
# 25/25 [==============================] - 2s 78ms/step - loss: 1.3513e-04 - accuracy: 1.0000 - val_loss: 1.5922 - val_accuracy: 0.7200
# Epoch 52/100
# 25/25 [==============================] - 2s 75ms/step - loss: 1.2876e-04 - accuracy: 1.0000 - val_loss: 1.5990 - val_accuracy: 0.7200
# Epoch 53/100
# 25/25 [==============================] - 2s 73ms/step - loss: 1.2332e-04 - accuracy: 1.0000 - val_loss: 1.6091 - val_accuracy: 0.7200
# Epoch 54/100
# 25/25 [==============================] - 2s 74ms/step - loss: 1.1767e-04 - accuracy: 1.0000 - val_loss: 1.6127 - val_accuracy: 0.7200
# Epoch 55/100
# 25/25 [==============================] - 2s 74ms/step - loss: 1.1272e-04 - accuracy: 1.0000 - val_loss: 1.6183 - val_accuracy: 0.7200
# Epoch 56/100
# 25/25 [==============================] - 2s 81ms/step - loss: 1.0808e-04 - accuracy: 1.0000 - val_loss: 1.6255 - val_accuracy: 0.7200
# Epoch 57/100
# 25/25 [==============================] - 2s 81ms/step - loss: 1.0340e-04 - accuracy: 1.0000 - val_loss: 1.6327 - val_accuracy: 0.7200
# Epoch 58/100
# 25/25 [==============================] - 2s 84ms/step - loss: 9.9195e-05 - accuracy: 1.0000 - val_loss: 1.6400 - val_accuracy: 0.7200
# Epoch 59/100
# Epoch 80/100
# 25/25 [==============================] - 2s 83ms/step - loss: 4.5971e-05 - accuracy: 1.0000 - val_loss: 1.7461 - val_accuracy: 0.7150
# Epoch 81/100
# 25/25 [==============================] - 2s 90ms/step - loss: 4.4568e-05 - accuracy: 1.0000 - val_loss: 1.7512 - val_accuracy: 0.7150
# Epoch 82/100
# 25/25 [==============================] - 2s 85ms/step - loss: 4.3219e-05 - accuracy: 1.0000 - val_loss: 1.7544 - val_accuracy: 0.7150
# Epoch 83/100
# 25/25 [==============================] - 2s 94ms/step - loss: 4.2051e-05 - accuracy: 1.0000 - val_loss: 1.7608 - val_accuracy: 0.7150
# Epoch 84/100
# 25/25 [==============================] - 2s 91ms/step - loss: 4.0815e-05 - accuracy: 1.0000 - val_loss: 1.7627 - val_accuracy: 0.7150
# Epoch 85/100
# 25/25 [==============================] - 3s 107ms/step - loss: 3.9642e-05 - accuracy: 1.0000 - val_loss: 1.7671 - val_accuracy: 0.7150
# Epoch 86/100
# 25/25 [==============================] - 2s 93ms/step - loss: 3.8507e-05 - accuracy: 1.0000 - val_loss: 1.7725 - val_accuracy: 0.7150
# Epoch 87/100
# 25/25 [==============================] - 2s 93ms/step - loss: 3.7505e-05 - accuracy: 1.0000 - val_loss: 1.7743 - val_accuracy: 0.7200
# Epoch 88/100
# 25/25 [==============================] - 2s 95ms/step - loss: 3.6426e-05 - accuracy: 1.0000 - val_loss: 1.7794 - val_accuracy: 0.7200
# Epoch 89/100
# 25/25 [==============================] - 2s 84ms/step - loss: 3.5385e-05 - accuracy: 1.0000 - val_loss: 1.7831 - val_accuracy: 0.7200
# Epoch 90/100
# 25/25 [==============================] - 2s 86ms/step - loss: 3.4515e-05 - accuracy: 1.0000 - val_loss: 1.7884 - val_accuracy: 0.7200
# Epoch 91/100
# 25/25 [==============================] - 2s 81ms/step - loss: 3.3536e-05 - accuracy: 1.0000 - val_loss: 1.7905 - val_accuracy: 0.7200
# Epoch 92/100
# 25/25 [==============================] - 2s 88ms/step - loss: 3.2617e-05 - accuracy: 1.0000 - val_loss: 1.7931 - val_accuracy: 0.7200
# Epoch 93/100
# 25/25 [==============================] - 2s 87ms/step - loss: 3.1803e-05 - accuracy: 1.0000 - val_loss: 1.7975 - val_accuracy: 0.7200
# Epoch 94/100
# 25/25 [==============================] - 2s 95ms/step - loss: 3.0962e-05 - accuracy: 1.0000 - val_loss: 1.8027 - val_accuracy: 0.7200
# Epoch 95/100
# 25/25 [==============================] - 2s 95ms/step - loss: 3.0148e-05 - accuracy: 1.0000 - val_loss: 1.8063 - val_accuracy: 0.7200
# Epoch 96/100
# 25/25 [==============================] - 2s 92ms/step - loss: 2.9349e-05 - accuracy: 1.0000 - val_loss: 1.8081 - val_accuracy: 0.7200
# Epoch 97/100
# 25/25 [==============================] - 2s 91ms/step - loss: 2.8633e-05 - accuracy: 1.0000 - val_loss: 1.8138 - val_accuracy: 0.7150
# Epoch 98/100
# 25/25 [==============================] - 2s 99ms/step - loss: 2.7921e-05 - accuracy: 1.0000 - val_loss: 1.8155 - val_accuracy: 0.7200
# Epoch 99/100
# 25/25 [==============================] - 2s 95ms/step - loss: 2.7182e-05 - accuracy: 1.0000 - val_loss: 1.8203 - val_accuracy: 0.7200
# Epoch 100/100
# 25/25 [==============================] - 2s 86ms/step - loss: 2.6503e-05 - accuracy: 1.0000 - val_loss: 1.8237 - val_accuracy: 0.7200
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
