# %% [markdown]
# Import Bib

# %%
# utilisée pour les calculs mathématiques en Python, spécialement pour les tableaux à plusieurs dimensions.
import numpy as np
#  convertir des données textuelles en séquences numériques qui peuvent être utilisées comme entrées pour les réseaux de neurones.
from keras.preprocessing.text import Tokenizer
# permet d'assurer que toutes les séquences de données ont la même longueur et peuvent donc être utilisées comme entrées pour le modèle,ajoutant des zéros à la fin des séquences plus courtes pour s'assurer que toutes les entrées ont la même longueur 
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Sequential est une classe de Keras qui permet de définir et créer des modèles de réseaux de neurones séquentiels en permettant d'ajouter les couches du modèle les unes après les autres de manière simple et conviviale
from keras.models import Sequential
# import des couches Embedding[vecteur de densite latente], GRU et Dense(effectuer les calculs de regression) pour le modèle RNN
from keras.layers import Embedding, GRU, Dense 
# stocker et manipuler des données tabulaires, telles que des tableaux de données enregistrés dans des fichiers CSV
import pandas as pd

import keras
import pickle 
from keras.models import load_model

# %% [markdown]
# Create Model

# %%
# Chargement des données de sentiments préparées dans un DataFrame de Pandas
data = pd.read_csv('yelp.csv')

# Séparation des données en entrée (textes) et étiquettes (sentiments)
texts = data['sentence'].values # tous les textes sont stockés dans le tableau texts
labels = data['label'].values # toutes les étiquettes sont stockées dans le tableau labels

# Tokenisation des textes
tokenizer = Tokenizer(num_words=10000) # définition du tokenizer avec une limite de 10000 mots
tokenizer.fit_on_texts(texts) # entraînement du tokenizer sur les textes
# tokenizer.fit_on_texts(texts) entraîne le tokenizer sur les textes. Cela signifie que le tokenizer analyse les textes et crée un dictionnaire de mots uniques, avec un identifiant unique pour chaque mot.
sequences = tokenizer.texts_to_sequences(texts) # tokenisation des textes
# effectue la tokenisation des textes. Cela signifie que le tokenizer convertit chaque séquence de textes en une séquence d'identificateurs uniques. Les séquences de textes sont remplacées par des séquences d'entiers, où chaque entier représente un mot unique dans le dictionnaire créé lors de l'entraînement.

# Pad sequences pour avoir la même longueur pour tous les textes
padded_sequences = pad_sequences(sequences, maxlen=100) # padding des séquences de tokenisation pour toutes les avoir de la même longueur

# Définition du modèle RNN
model = Sequential([
    Embedding(10000, 128, input_length=100), # première couche : embedding
       GRU(128), # deuxième couche : GRU
     Dense(1, activation='sigmoid') # troisième couche : dense avec une activation sigmoïde pour avoir un output binaire
   ])

# Compilation du modèle
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # choix de la fonction de coût, de l'optimiseur et des métriques à suivre lors de l'entraînement

# Entraînement du modèle

history = model.fit(padded_sequences, labels, epochs=100, validation_split=0.2) # entraînement sur les séquences padded et les étiquettes avec 10 epochs et une validation sur 20% des données
# Après l'entraînement
model.save('sentiment_analysis_model.h5')


# Sauvegarde du tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 9s 150ms/step - loss: 0.6776 - accuracy: 0.5612 - val_loss: 0.8149 - val_accuracy: 0.2400
# Epoch 2/100
# 25/25 [==============================] - 3s 118ms/step - loss: 0.6628 - accuracy: 0.6900 - val_loss: 0.4376 - val_accuracy: 0.8150
# Epoch 3/100
# 25/25 [==============================] - 3s 113ms/step - loss: 0
# 25/25 [==============================] - 4s 145ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.8743 - val_accuracy: 0.7150
# Epoch 31/100
# 25/25 [==============================] - 4s 142ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8850 - val_accuracy: 0.7150
# Epoch 32/100
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.8934 - val_accuracy: 0.7150
# Epoch 33/100
# 25/25 [==============================] - 6s 233ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.9079 - val_accuracy: 0.7100
# Epoch 34/100
# 25/25 [==============================] - 6s 220ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.9165 - val_accuracy: 0.7100
# Epoch 35/100
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9307 - val_accuracy: 0.7050
# Epoch 36/100
# 25/25 [==============================] - 5s 188ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9363 - val_accuracy: 0.7050
# Epoch 37/100
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9487 - val_accuracy: 0.7050
# Epoch 38/100
# 25/25 [==============================] - 3s 136ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9553 - val_accuracy: 0.7050
# Epoch 39/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9655 - val_accuracy: 0.7100
# Epoch 40/100
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9748 - val_accuracy: 0.7050
# Epoch 41/100
# 25/25 [==============================] - 5s 173ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9830 - val_accuracy: 0.7050
# Epoch 42/100
# 25/25 [==============================] - 10s 383ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.9936 - val_accuracy: 0.7050
# Epoch 43/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.0031 - val_accuracy: 0.7050
# Epoch 44/100
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0080 - val_accuracy: 0.7100
# Epoch 45/100
# 25/25 [==============================] - 4s 153ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0175 - val_accuracy: 0.7100
# Epoch 46/100
# 25/25 [==============================] - 4s 157ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0257 - val_accuracy: 0.7100
# Epoch 47/100
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0328 - val_accuracy: 0.7100
# Epoch 48/100
# 25/25 [==============================] - 4s 163ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0429 - val_accuracy: 0.7100
# Epoch 49/100
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0486 - val_accuracy: 0.7150
# Epoch 50/100
# 25/25 [==============================] - 5s 191ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0558 - val_accuracy: 0.7150
# Epoch 51/100
# 25/25 [==============================] - 3s 138ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.0650 - val_accuracy: 0.7150
# Epoch 52/100
# 25/25 [==============================] - 4s 147ms/step - loss: 9.7609e-04 - accuracy: 1.0000 - val_loss: 1.0709 - val_accuracy: 0.7150
# Epoch 53/100
# 25/25 [==============================] - 4s 149ms/step - loss: 9.2700e-04 - accuracy: 1.0000 - val_loss: 1.0794 - val_accuracy: 0.7100
# Epoch 54/100
# 25/25 [==============================] - 3s 135ms/step - loss: 8.7199e-04 - accuracy: 1.0000 - val_loss: 1.0863 - val_accuracy: 0.7100
# Epoch 55/100
# 25/25 [==============================] - 4s 144ms/step - loss: 8.3040e-04 - accuracy: 1.0000 - val_loss: 1.0930 - val_accuracy: 0.7100
# Epoch 56/100
# 25/25 [==============================] - 4s 144ms/step - loss: 7.9115e-04 - accuracy: 1.0000 - val_loss: 1.1001 - val_accuracy: 0.7100
# Epoch 57/100
# 25/25 [==============================] - 4s 164ms/step - loss: 7.5297e-04 - accuracy: 1.0000 - val_loss: 1.1068 - val_accuracy: 0.7050
# Epoch 58/100
# 25/25 [==============================] - 8s 308ms/step - loss: 7.1940e-04 - accuracy: 1.0000 - val_loss: 1.1140 - val_accuracy: 0.7050
# Epoch 59/100
# 25/25 [==============================] - 6s 225ms/step - loss: 6.8249e-04 - accuracy: 1.0000 - val_loss: 1.1198 - val_accuracy: 0.7050
# Epoch 60/100
# 25/25 [==============================] - 5s 196ms/step - loss: 6.5353e-04 - accuracy: 1.0000 - val_loss: 1.1259 - val_accuracy: 0.7050
# Epoch 61/100
# 25/25 [==============================] - 7s 294ms/step - loss: 6.2236e-04 - accuracy: 1.0000 - val_loss: 1.1344 - val_accuracy: 0.7050
# Epoch 82/100
# 25/25 [==============================] - 4s 161ms/step - loss: 2.7363e-04 - accuracy: 1.0000 - val_loss: 1.2531 - val_accuracy: 0.7150
# Epoch 83/100
# 25/25 [==============================] - 6s 233ms/step - loss: 2.6411e-04 - accuracy: 1.0000 - val_loss: 1.2586 - val_accuracy: 0.7150
# Epoch 84/100
# 25/25 [==============================] - 4s 149ms/step - loss: 2.5647e-04 - accuracy: 1.0000 - val_loss: 1.2622 - val_accuracy: 0.7150
# Epoch 85/100
# 25/25 [==============================] - 5s 194ms/step - loss: 2.4771e-04 - accuracy: 1.0000 - val_loss: 1.2687 - val_accuracy: 0.7150
# Epoch 86/100
# 25/25 [==============================] - 4s 171ms/step - loss: 2.3954e-04 - accuracy: 1.0000 - val_loss: 1.2738 - val_accuracy: 0.7150
# Epoch 87/100
# 25/25 [==============================] - 4s 163ms/step - loss: 2.3157e-04 - accuracy: 1.0000 - val_loss: 1.2794 - val_accuracy: 0.7150
# Epoch 88/100
# 25/25 [==============================] - 3s 105ms/step - loss: 2.2437e-04 - accuracy: 1.0000 - val_loss: 1.2839 - val_accuracy: 0.7150
# Epoch 89/100
# 25/25 [==============================] - 3s 114ms/step - loss: 2.1752e-04 - accuracy: 1.0000 - val_loss: 1.2890 - val_accuracy: 0.7150
# Epoch 90/100
# 25/25 [==============================] - 7s 269ms/step - loss: 2.1107e-04 - accuracy: 1.0000 - val_loss: 1.2927 - val_accuracy: 0.7150
# Epoch 91/100
# 25/25 [==============================] - 8s 303ms/step - loss: 2.0422e-04 - accuracy: 1.0000 - val_loss: 1.2974 - val_accuracy: 0.7150
# Epoch 92/100
# 25/25 [==============================] - 8s 317ms/step - loss: 1.9893e-04 - accuracy: 1.0000 - val_loss: 1.3031 - val_accuracy: 0.7100
# Epoch 93/100
# 25/25 [==============================] - 6s 231ms/step - loss: 1.9195e-04 - accuracy: 1.0000 - val_loss: 1.3073 - val_accuracy: 0.7100
# Epoch 94/100
# 25/25 [==============================] - 4s 157ms/step - loss: 1.8637e-04 - accuracy: 1.0000 - val_loss: 1.3132 - val_accuracy: 0.7100
# Epoch 95/100
# 25/25 [==============================] - 3s 121ms/step - loss: 1.8151e-04 - accuracy: 1.0000 - val_loss: 1.3164 - val_accuracy: 0.7100
# Epoch 96/100
# 25/25 [==============================] - 3s 107ms/step - loss: 1.7581e-04 - accuracy: 1.0000 - val_loss: 1.3218 - val_accuracy: 0.7100
# Epoch 97/100
# 25/25 [==============================] - 2s 99ms/step - loss: 1.7037e-04 - accuracy: 1.0000 - val_loss: 1.3262 - val_accuracy: 0.7100
# Epoch 98/100
# 25/25 [==============================] - 3s 104ms/step - loss: 1.6529e-04 - accuracy: 1.0000 - val_loss: 1.3296 - val_accuracy: 0.7100
# Epoch 99/100
# 25/25 [==============================] - 2s 82ms/step - loss: 1.6111e-04 - accuracy: 1.0000 - val_loss: 1.3342 - val_accuracy: 0.7100
# Epoch 100/100
# 25/25 [==============================] - 2s 81ms/step - loss: 1.5619e-04 - accuracy: 1.0000 - val_loss: 1.3397 - val_accuracy: 0.7100
# c:\Users\XPS\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
